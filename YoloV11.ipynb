# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoska1/driving-comfort-yolo11/blob/main/YoloV11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
os.chdir('/v11')
print("Current directory :", os.getcwd())
# Out:
# Current directory : /v11

# %%
# !pip install ultralytics

# %%
# !pip install -q roboflow

# %%
# %cd {HOME}/ultralytics
# Out:
# [Errno 2] No such file or directory: '/content/ultralytics'
# /content

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="IxXkXChvKvzhRnqjmm23")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(12)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-12 in yolov11:: 100%|██████████| 756/756 [00:00<00:00, 1503.16it/s]

# %%
print(dataset.location)
# !mv {dataset.location}/train {HOME}/ultralytics
# !mv {dataset.location}/valid {HOME}/ultralytics
# Out:
# /content/football-players-detection-12

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m.yaml")
model = YOLO("yolo11m.pt")
model = YOLO("yolo11n.yaml").load("yolo11n.pt")

results = model.train(data="coco8.yaml", epochs=100, imgsz=640) # change coco8.yaml
# Out:
#   File "<ipython-input-8-0b522c784fa3>", line 28
#     yolo detect train data = /path/to/image.yaml \
#          ^
# SyntaxError: invalid syntax

# %%
# !pip install opencv-python ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.1/922.1 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.13
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.4
# ale-py                             0.10.2
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.2.24.0.34.4
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
import cv2
from ultralytics import YOLO

model = YOLO("yolo11x.pt")
# Out:
# ...
# 100%|██████████| 109M/109M [00:00<00:00, 252MB/s]

# %%
# Out:
# sample_data
